# %%
import pandas as pd

# %%
df = pd.read_csv("data/fighters_stats.csv")
df
# Out:
#     Aggression  Defense  Health  Won
# 0            9        2      65  Yes
# 1            8        3      70  Yes
# 2            7        4      68  Yes
# 3            6        6      85   No
# 4            5        8      90   No
# 5            4        9      92   No
# 6            9        5      72  Yes
# 7            8        6      75  Yes
# 8            3       10      95   No
# 9            2        9      98   No
# 10           7        3      74  Yes
# 11           6        4      76  Yes
# 12           5        5      82   No
# 13           4        6      88   No
# 14           9        4      70  Yes
# 15           8        5      73  Yes
# 16           3        8      91   No
# 17           2       10      99   No
# 18           9        3      68  Yes
# 19           8        4      72  Yes
# 20           5        7      85   No
# 21           6        8      89   No
# 22           7        2      66  Yes
# 23           4        9      93   No
# 24           9        6      77  Yes
# 25           7        5      80   No
# 26           8        7      83  Yes
# 27           5        9      90   No
# 28           6        3      71  Yes
# 29           4        7      88   No

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

X = df[['Aggression', 'Defense', 'Health']]
y = df['Won']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = DecisionTreeClassifier(max_depth=3, random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
plt.figure(figsize=(10,6))
plot_tree(clf, feature_names=['Aggression', 'Defense', 'Health'], class_names=['No', 'Yes'], filled=True, fontsize=15)
plt.show()

# %%
from sklearn.metrics import accuracy_score

y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
